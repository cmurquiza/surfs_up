# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# Import the sqlalchemy extract function.
from sqlalchemy import extract

# 1. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
# 2. Convert the June temperatures to a list.
june_results = []
june_results = session.query(Measurement.station, Measurement.date, Measurement.prcp, Measurement.tobs).filter(extract('month', Measurement.date)==6).all()

# %%
# 3. Create a DataFrame from the list of temperatures for the month of June. 
df_june = pd.DataFrame(results, columns=['station','date','precipitation','june temperatures'])
# By setting inplace=True, we're saying that we do not want to create a new DataFrame with the modified specifications.
df_june.set_index(df_june['date'], inplace=True)
# Sorts the values by date
df_june = df_june.sort_index()
# Print the Dataframe without the index
print(df_june.to_string(index=False))
# Out:
#     station       date  precipitation  june temperatures
# USC00519397 2010-12-01           0.04               76.0
# USC00514830 2010-12-01           0.03               73.0
# USC00517948 2010-12-01           0.70               72.0
# USC00519523 2010-12-01           0.03               78.0
# USC00519281 2010-12-01           1.35               72.0
# USC00511918 2010-12-01           0.13               70.0
# USC00516128 2010-12-01           1.48               71.0
# USC00513117 2010-12-01           0.76               73.0
# USC00518838 2010-12-02            NaN               71.0
# USC00519281 2010-12-02           0.16               71.0
# USC00514830 2010-12-02           0.06               73.0
# USC00517948 2010-12-02           0.26               75.0
# USC00511918 2010-12-02           0.00               74.0
# USC00513117 2010-12-02           0.13               72.0
# USC00519523 2010-12-02           0.02               74.0
# ...

# %%
# 4. Calculate and print out the summary statistics for the June temperature DataFrame.
df_june.describe()
# Out:
#        precipitation  june temperatures
# count    1405.000000        1517.000000
# mean        0.216819          71.041529
# std         0.541399           3.745920
# min         0.000000          56.000000
# 25%         0.000000          69.000000
# 50%         0.030000          71.000000
# 75%         0.150000          74.000000
# max         6.420000          83.000000

# %%
# 5. Return to your challenge instructions to compare your summary statistics

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
# 7. Convert the December temperatures to a list.
december_results = []
december_results = session.query(Measurement.station, Measurement.date, Measurement.prcp, Measurement.tobs).filter(extract('month', Measurement.date)==12).all()

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
# 3. Create a DataFrame from the list of temperatures for the month of June. 
df_december = pd.DataFrame(results, columns=['station','date','precipitation','december temperatures'])
# By setting inplace=True, we're saying that we do not want to create a new DataFrame with the modified specifications.
df_december.set_index(df_december['date'], inplace=True)
# Sorts the values by date
df_december = df_december.sort_index()
# Print the Dataframe without the index
print(df_december.to_string(index=False))
# Out:
#     station       date  precipitation  december temperatures
# USC00519397 2010-12-01           0.04                   76.0
# USC00514830 2010-12-01           0.03                   73.0
# USC00517948 2010-12-01           0.70                   72.0
# USC00519523 2010-12-01           0.03                   78.0
# USC00519281 2010-12-01           1.35                   72.0
# USC00511918 2010-12-01           0.13                   70.0
# USC00516128 2010-12-01           1.48                   71.0
# USC00513117 2010-12-01           0.76                   73.0
# USC00518838 2010-12-02            NaN                   71.0
# USC00519281 2010-12-02           0.16                   71.0
# USC00514830 2010-12-02           0.06                   73.0
# USC00517948 2010-12-02           0.26                   75.0
# USC00511918 2010-12-02           0.00                   74.0
# USC00513117 2010-12-02           0.13                   72.0
# ...

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
df_december.describe()
# Out:
#        precipitation  december temperatures
# count    1405.000000            1517.000000
# mean        0.216819              71.041529
# std         0.541399               3.745920
# min         0.000000              56.000000
# 25%         0.000000              69.000000
# 50%         0.030000              71.000000
# 75%         0.150000              74.000000
# max         6.420000              83.000000

# %%
# 10. Return to your challenge instructions to compare your summary statistics
